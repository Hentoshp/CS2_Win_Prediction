# %%
# Importing required libraries
import numpy as np
import pandas as pd
import requests
import time
from auth_key import get_auth_key

# %%
auth_key = get_auth_key()

# %%
# Takes player nickname and auth_key as arguements and returns player id and elo as columns of dataframe
def get_player_data(nickname, auth_key):

    # parameters for requests func
    parameters = {
        "nickname": nickname 
    }
    
    # faceit url for player id data
    url_player_id = "https://open.faceit.com/data/v4/players"

    # API key
    headers = {
    "Authorization": auth_key
    }

    # requesting player info from API
    response = requests.get(url_player_id, 
                            headers = headers, 
                            params = parameters)


    # conditional to catch request errors
    if response.status_code == 404:
        print(f"Error 404: Resource not found. Requested URL: {response.url}")
        
        # Return empty dataframe
        stats = pd.DataFrame()
        return stats
        
    elif response.status_code == 200:
        player_data = response.json()

        # try/except statement to catch KeyErrors 
        try:
            player_data_dict = {"player_id": player_data['player_id'],
                            "faceit_elo": player_data["games"]["cs2"]["faceit_elo"]}
            player_data_df = pd.DataFrame([player_data_dict])
            
        except KeyError:
            # KeyErrors generally occur due to CSGO match ID
            print("match_id for CSGO")
            
             # Returns empty dataframe
            stats = pd.DataFrame()
            return stats
            
            
        
        return player_data_df

    # for uncommon request errors
    else:
        print(f"Error {response.status_code}: {response.text}")
        stats = pd.DataFrame()
        return stats

# %%
# returns player stats for the last 100 games played (if 100 games exist)
def get_player_stats(player_id, auth_key):
    
    
    # parameters needed for API request
    parameters = {
        "player_id": player_id,
        "limit": 100
    }

    # URL used for API request
    game_id = "cs2"
    url_stats = f"https://open.faceit.com/data/v4/players/{player_id}/games/{game_id}/stats"
    
    headers = {
        "Authorization": auth_key
    }


    # requests player data for last 100 games
    response = requests.get(url_stats, 
                            headers = headers, 
                            params = parameters)

    # Flattens nested json into dataframe
    data = response.json()
    stats_df = pd.json_normalize(data['items'], sep = '_')

    # returns player stats dataframe
    return stats_df

# %%
# Takes player stats dataframe and match map and returns individual player stats for that map
def player_stats_calc(df, map):
    
    # testing if map exists
    try:
        test_df = df[df.stats_Map == map]
    # If map does not exist return empty dataframe
    except:
        stats = pd.DataFrame()
        return stats

    
    # Converting Result and K/R ratio columns to numeric
    test_df.loc[:, ['stats_Result']] = pd.to_numeric(test_df['stats_Result'])
    test_df.loc[:, ['stats_K/R Ratio']] = pd.to_numeric(test_df['stats_K/R Ratio'])
        

    try:
        # Calculating win percentage
        map_win_percentage = (test_df['stats_Result'].sum() / len(test_df)) * 100
        
    except ZeroDivisionError:
        stats = pd.DataFrame()
        print("ZeroDivisonError")
        return stats

        
        
    try:
        # Calculating average K/R ratio
        average_KR_ratio = test_df['stats_K/R Ratio'].mean()
    
    except ZeroDivisionError:    
        stats = pd.DataFrame()
        print("ZeroDivisonError")
        return stats
        
    
    # Combining stats and renaming axis for data frame
    stats = pd.DataFrame({"Win Percentage": map_win_percentage,
                         "Average K/R Ratio": average_KR_ratio}, index = [0])
    # returning stats data frame
    return stats

# %%
# Pulls player ID from leaderboard
def get_ranking_player_ids(offset, auth_key):

    # requests parameters
    parameters = {
        "offset": offset,
        "limit": 100
    }
    region = "NA"
    game_id = "cs2"
    url_leaderboard = f"https://open.faceit.com/data/v4/rankings/games/{game_id}/regions/{region}"
    headers = {
        "Authorization": auth_key
    }
    
    
    # requesting API for 100 players' data from leaderboard
    response = requests.get(url_leaderboard, 
                            headers = headers, 
                            params = parameters)

    # Conditional to catch API request errors
    if response.status_code == 404:
        print("Error 404: Resource not found.")
        print(f"Requested URL: {response.url}")

    # Flattening nested json into dataframe
    elif response.status_code == 200:
        data = response.json()
        data_frame_rankings = pd.json_normalize(data['items'], 
                                                sep = '_')
        
    # Extracting player_id column
        return data_frame_rankings['player_id']
        
    else:
        print(f"Error {response.status_code}: {response.text}")

# %%
# Uses player ID to pull 3 match_id from match histroy
def match_data_selection(player_id, auth_key):

    # parameters for API request
    parameters = {
        "limit": 3
    }
    url_match_history = f"https://open.faceit.com/data/v4/players/{player_id}/history"

    # requesting match history from API for player
    response = requests.get(url_match_history, 
                            headers = headers, 
                            params = parameters)

    # Conditional to check for request errors
    if response.status_code == 200:

        # Flattening JSON to dataframe
        data = response.json()
        df_match_id = pd.json_normalize(data['items'], 
                                        sep = '_')

        # returning match_id column
        return df_match_id['match_id']
        
    else:
        print(f"Error {response.status_code}: {response.text}")

# %%
# Uses match_ID to calculate dataframe of match stats for each team
def calculate_match_stats(match_id, auth_key, count):

    # parameters for API request
    headers = {
        "Authorization": auth_key
        }
    url_match_id = f"https://open.faceit.com/data/v4/matches/{match_id}/stats"

    # API request for match statsitics
    response = requests.get(url_match_id, 
                            headers = headers)
        

    # Flattens nested json
    match_data = response.json()

    # attempts to flatten nested JSON
    try:
        rounds_flat = pd.json_normalize(match_data['rounds'], 
                                        sep = '_')
    # returns empty dataframe if rounds does not exist 
    except KeyError:
        stats = pd.DataFrame()
        return stats
    
    # Flatten teams, nested in match_data
    teams_flat = pd.json_normalize(
        match_data['rounds'],
        record_path = 'teams',
        meta = ['match_id'],
        sep = '_'
    )
    
    # Flatten players data
    players_flat = pd.json_normalize(
        match_data['rounds'],
        record_path = ['teams', 'players'],
        meta = ['match_id', ['teams', 'team_id']],
        sep = '_'
    )

    # flatten teams data
    teams_df = pd.json_normalize(match_data['rounds'], 
                                 record_path = 'teams', 
                                 meta = ['match_id'], 
                                 sep = '_')
    
    # creating columns for match data frame
    columns = ["win", "map", "Team_A_avg_win_percentage", "Team_A_avg_KR", "Team_A_avg_elo",
                  "Team_B_avg_win_percentage", "Team_B_avg_KR", "Team_B_avg_elo", "Match ID"]

    # creating match data frame
    
    data_df = pd.DataFrame(columns = columns)
    data_df.columns

    # checking if match data exists, or returns empty dataframe
    try:
        if teams_df.loc[0, 'team_stats_Team Win'] == "1":
            data_df.loc[0, "win"] = "team a"
        else:
            data_df.loc[0, "win"] = "team b"
        data_df.loc[0, "map"] = rounds_flat.round_stats_Map[0]
    
        data_df.loc[0, "Match ID"] = teams_df.match_id[0]
        
    except KeyError:
        stats = pd.DataFrame()
        return stats
    

    
    
    # Team A Stats
    team_a_df = pd.DataFrame(teams_df.players[0])
    
    team_a_nicknames = team_a_df.nickname
    team_a_id_elo_list = []

    # loops over nicknames column and appends list of player ids for team A
    for nickname in team_a_nicknames:
        id_elo = get_player_data(nickname, auth_key)
        
        # returns empty dataframe if player elo DNE
        if id_elo.empty:
            print(count)
            return id_elo
        else:
            team_a_id_elo_list.append(id_elo)

    # creates column of player IDs from list
    team_a_id_elo_df = pd.concat(team_a_id_elo_list)

    # adds mean of team elo to match data df
    data_df.loc[0 , "Team_A_avg_elo"] = team_a_id_elo_df["faceit_elo"].mean()
    
    # Uses player ID to calculate individual player stats (K/R and win percentage)
    team_a_stats_list = []
    for id in team_a_df.player_id:
        # uses get_player_stats to calculate individual stats
        stats_df = get_player_stats(id, auth_key)
        stats = player_stats_calc(stats_df, data_df["map"][0])
        # if returned df is empty, return empty match dataframe
        if stats.empty:
            # used to track missing/invalid data
            print(count)
            print("Unable to compute stats, may be error with map used")
            return stats

        # append individual stats to list
        else: 
            team_a_stats_list.append(stats)

    # creates win percentage and K/R ratio columns for team A 
    team_a_stats_df = pd.concat(team_a_stats_list)
    data_df.loc[0 , "Team_A_avg_win_percentage"] = team_a_stats_df["Win Percentage"].mean()
    data_df.loc[0 , "Team_A_avg_KR"] = team_a_stats_df["Average K/R Ratio"].mean()
        
    
    
    
    
    # Team B stats, repeats same process used for team A stats
    
    team_b_df = pd.DataFrame(teams_df.players[1])
    team_b_nicknames = team_b_df.nickname
    team_b_id_elo_list = []
    
    for nickname in team_b_nicknames:
        
        if id_elo.empty:
            print(count)
            return id_elo
            
        else:
            team_b_id_elo_list.append(id_elo)
    
    team_b_id_elo_df = pd.concat(team_b_id_elo_list)
    team_b_id_elo_df
    data_df.loc[0 , "Team_B_avg_elo"] = team_b_id_elo_df["faceit_elo"].mean()
    
    
    team_b_stats_list = []
    for id in team_b_df.player_id:
        
        stats_df = get_player_stats(id, auth_key)
        stats = player_stats_calc(stats_df, data_df["map"][0])
        
        if stats.empty:
            print(count)
            print("Unable to compute stats, may be error with map used")
            return stats
            
        else: 
            team_b_stats_list.append(stats)
            
    team_b_stats_df = pd.concat(team_b_stats_list)
    data_df.loc[0 , "Team_B_avg_win_percentage"] = team_b_stats_df["Win Percentage"].mean()
    data_df.loc[0 , "Team_B_avg_KR"] = team_b_stats_df["Average K/R Ratio"].mean()

    # Returns row of match data for match_id given
    return data_df

# %%
# Creates excel file to store player_ids
excel_filename_player_id = 'player_ids_new.xlsx'
with pd.ExcelWriter(excel_filename_player_id, engine = 'openpyxl', mode = 'w') as writer:
    pd.DataFrame().to_excel(writer, index = False)

# %%
# pulls 100 player ids from ranking leaderboard each iteration
# offset parameter determines starting point of pull, helps when API call times out
offset = 49700
while offset < 50000:
    player_df = get_ranking_player_ids(offset, auth_key)
    offset += 100
    
    with pd.ExcelWriter(excel_filename, engine = 'openpyxl', mode = 'a', if_sheet_exists = 'overlay') as writer:
        player_df.to_excel(writer, index = False, header = offset == 0, startrow = writer.sheets['Sheet1'].max_row)

# %%
# Reading in player ID dataframe
player_ids_df = pd.read_excel("player_ids.xlsx")
player_ids_df.columns = ["player_ids"]
player_ids_df
# Out:
#                                  player_ids
# 0      884d38aa-b92e-420a-ab15-0d600087c366
# 1      e8f354c3-337e-4d64-b2a8-c681262c8ed8
# 2      93849291-b93b-47a4-8351-b05d8d7026a5
# 3      71ea9955-8400-4553-87a5-4c325923d21f
# 4      e1c8511d-52b8-4c21-a781-1157d201a9f6
# ...                                     ...
# 49995  1c230639-c8a4-4848-8e8b-5cc226d080ed
# 49996  15658775-7875-48b6-8d82-69764be488b5
# 49997  155b18ef-fd97-4121-a691-444180a6a5d0
# 49998  0a7370b4-dfe2-4e71-84f7-41c868180520
# 49999  0917452d-2968-4500-8ad4-f6ba0524d00f
#
# [50000 rows x 1 columns]

# %%
# taking random sample from player_id df
player_ids_sample_df = player_ids_df.sample(n = 100)
player_ids_sample_df
# Out:
#                                  player_ids
# 11709  d887bdad-0aed-48d9-9b6c-15f56e8a61ec
# 32111  0a1d3574-0e40-4836-a26a-1ef4f85fc9e1
# 10668  13004c45-a23c-4d1c-b714-5ef3391e0367
# 31249  135007ec-80bb-468e-82d7-4902c6b8e948
# 30673  fdc094f8-d20a-471c-9654-a37cc247960a
# ...                                     ...
# 9368   b9624f14-b818-4e77-ba58-2a4176da4639
# 15780  c470d0d4-ecda-41df-9ec0-83115a6363c8
# 5234   79447dc3-8db6-490f-a650-9e5e8b48c773
# 26730  3c6e7053-90f3-42ef-a3fd-a29dd0c56405
# 3808   f470a0d4-6c15-4f33-b8a9-1edfd79cbb40
#
# [1000 rows x 1 columns]

# %%
# creating excel sheet for match_ids
excel_filename_match_id = 'match_ids.xlsx'
with pd.ExcelWriter(excel_filename_match_id, engine = 'openpyxl', mode = 'w') as writer:
     pd.DataFrame().to_excel(writer, index = False)

# %%
# Applys match_data_selection over player_id sampled dataframe
match_ids_expanded = player_ids_sample_df["player_ids"].apply(lambda x: match_data_selection(x, auth_key))

# creates dataframe out of match_ids
match_ids_expanded = match_ids_expanded.melt(value_name = "match_id").dropna()[["match_id"]]
match_ids_expanded
# Out:
#                                     match_id
# 0     1-fe4702c6-f6c6-48ca-a81b-0aedc8f31444
# 1     1-051c5a18-6a99-4e5e-bef7-ed1143474b33
# 2     1-8f29e3ec-f49d-4d05-8eac-98993126c405
# 3     1-a40b6b42-9441-4681-9206-a2085e92f800
# 4     1-c33343e1-5b8f-4cca-995b-20685ec33746
# ...                                      ...
# 2995  1-da5d765d-5ff7-4ef2-b746-2e95463b015a
# 2996  1-5acfd781-934e-4155-900f-c5318babd62a
# 2997  1-8f51de72-a949-4a55-b782-5f2b359a5e10
# 2998  1-ba8a9159-2d8b-45b6-b56e-f071a5e5189c
# 2999  1-10e89983-5866-4def-bd52-e76518f853d4
#
# [2999 rows x 1 columns]

# %%
# Appending match_id data to match_id excel sheet
with pd.ExcelWriter(excel_filename_match_id, engine = 'openpyxl', mode = 'a', if_sheet_exists = 'overlay') as writer:
        match_ids_expanded.to_excel(writer, index = False, header = offset == 0, startrow = writer.sheets['Sheet1'].max_row)

# %%
# Used for tracking missing/invalid data while calulating match stats
count = 0
calculate_match_stats(match_ids_expanded["match_id"][1428], 
                      auth_key, 
                      count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 3
#       1 # Used for tracking missing/invalid data while calulating match stats
#       2 count = 0
# ----> 3 calculate_match_stats(match_ids_expanded["match_id"][1428],
#       4                       auth_key,
#       5                       count)
#
# NameError: name 'match_ids_expanded' is not defined

# %%
# Creating excel sheet to store data for win prediction
excel_filename_data_win  = "data_win_prediction.xlsx"
with pd.ExcelWriter(excel_filename_data_win, engine = 'openpyxl', mode = 'w') as writer:
    pd.DataFrame().to_excel(writer, index = False)

# %%
# Loops over match_id column and returns match data row, then appends to excel file
count = 0
for match_id in match_ids_expanded["match_id"][2568:]:
    count += 1
    data_df = calculate_match_stats(match_id, auth_key, count)

    # Appends to data_win_predction excel sheet
    with pd.ExcelWriter(excel_filename_data_win, engine = 'openpyxl', mode = 'a', if_sheet_exists = 'overlay') as writer:
        data_df.to_excel(writer, index = False, header = offset == 0, startrow = writer.sheets['Sheet1'].max_row)

# delays iterations for API limits
time.sleep(3)
# Out:
# match_id for CSGO
# 1
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=adamha54
# 3
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=JCWCS
# 4
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1shrek
# 5
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Karnani02
# 9
# match_id for CSGO
# 14
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=oreosssss
# 16
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=prblmchld
# 18
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=vlre-
# 20
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=dak3-_-
# 21
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=yobrt
# 22
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=taf_peter
# 24
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ICEBERG0D
# 27
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=h3rcul1es
# 30
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-_-Serotonin
# 32
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=reminisce999
# 36
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Jermoni
# 40
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=GRIMANZZ
# 41
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Boop21
# 42
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=kou17
# 43
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=9volt
# 44
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=DaSchmonky
# 46
# ZeroDivisonError
# 48
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Palet
# 50
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Maj0n3zy
# 53
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=spicyranch
# 54
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Crohps
# 55
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=AshesAwaken
# 58
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=BLVCK-AG
# 61
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-hyun-
# 62
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=77STIKER77
# 64
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=z0mbiebean
# 65
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=SuperSauce_E
# 66
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=gortagian
# 67
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Quantization
# 71
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Coder3
# 72
# match_id for CSGO
# 74
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=syth_sucks
# 75
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=jshuwaa
# 77
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ERASEDDDD
# 78
# match_id for CSGO
# 79
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Nikeaj
# 80
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=mersaults
# 82
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=20tonfragger
# 83
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-BOSS_B-
# 85
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-Xner
# 86
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=MrRodrigoXD
# 87
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=---gerald---
# 89
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ya9proklyata
# 93
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Augie_
# 102
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-ICR
# 108
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=dnishkina
# 110
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Sh13lld
# 112
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=KUM_BAKEN
# 114
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=sewag0d
# 119
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1dalt0n
# 120
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=dreski89
# 122
# 123
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=nkoi2501
# 124
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Pool
# 125
# match_id for CSGO
# 128
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-Fxy
# 130
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=p1nk333
# 132
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=strokeNNN
# 134
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=JesusisKiing
# 135
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=toddyy666
# 138
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Femuto
# 140
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=El_Gr1ng0
# 141
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=--Minty--
# 144
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=jaydez_
# 148
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Caffrey_
# 149
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Hibui
# 152
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=xelarate
# 153
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=C4N0WSK1
# 155
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Tigertrojan
# 156
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=0sl0
# 157
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=iTryHard09
# 158
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Daz
# 161
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Dwayne_
# 162
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Nuclear-iwnl
# 163
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Zwooxx
# 164
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Rockport
# 168
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=xxT21
# 170
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=DeKa_-_
# 171
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=G2_Baba
# 174
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=garrettlover
# 175
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-Jake_-
# 176
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=_bud
# 177
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=--vale
# 178
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Laomokengb
# 181
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=nOr6er7
# 184
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=WaffyYT
# 185
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=cr3nc
# 186
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=w4llenATOMMM
# 187
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=nthgorcryjor
# 189
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Conath
# 190
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=noisess-
# 194
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=reyworld
# 196
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=CakesBaby
# 198
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=cedoi111
# 199
# ZeroDivisonError
# 200
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Hinoth
# 205
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=benlynn
# 206
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=7SKYL1NE7
# 208
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ysgpia
# 209
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=k0vi9
# 210
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=2M00
# 212
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=FlowerPick3r
# 213
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=L0VERRRRRRRR
# 214
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ceebeast
# 219
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=DIE6O
# 222
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Jee710
# 224
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=m0ck_
# 226
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Royzyc1
# 227
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Justeeno
# 228
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=J0RKIN
# 229
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ricky2shoez
# 231
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=nemmyTV
# 237
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1001001101
# 239
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=MoogieBrehh
# 244
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=--neu--
# 247
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Iookie
# 248
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=LabzDegen
# 251
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=---Neko--
# 253
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=yzku
# 255
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=nudder
# 257
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=MrLunt
# 259
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-sske-
# 260
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Jae_Yeol
# 261
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=soloflight
# 263
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ChiroOchx
# 264
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1-sn
# 265
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=geankobb25
# 266
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=RIZZINGOOF
# 267
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=desolat1onn-
# 270
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=FlexTTV
# 272
# match_id for CSGO
# 276
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Bill-iwnl-
# 280
# match_id for CSGO
# 281
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=chucky-hM
# 282
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Prince-47
# 283
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=XIUnRaTeD
# 285
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1000-Denials
# 286
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=BigShaq17
# 290
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=frankelitoc
# 291
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=MINOV
# 292
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=LsdRipZ
# 293
# match_id for CSGO
# 295
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=SnowySpycrab
# 296
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=LastNagger
# 297
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ajkoss_
# 298
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=skul1night
# 299
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=extia
# 300
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Flockyyyy
# 303
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=_HleboreZ_
# 306
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=_-bulleT
# 307
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-deso1ation
# 308
# ZeroDivisonError
# 309
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=AWhiteKid
# 310
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=iech
# 313
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Hn7r
# 314
# match_id for CSGO
# 325
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=2fuego
# 326
# ZeroDivisonError
# 327
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Bopped_ttv
# 328
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=TheCumThief
# 329
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=BIEM2708
# 331
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=oranoss
# 332
# ZeroDivisonError
# 333
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=CardoDlisay
# 337
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=hunger
# 339
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ShangayEU
# 340
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=FLOW71M3
# 341
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=X0---
# 344
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=N0RMIIE
# 345
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=--TEX
# 346
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Intense_CS
# 347
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Taesty
# 349
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-60hz-
# 350
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=iTwerk4percs
# 351
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=MAlNESTREAM
# 355
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=jackniwnl
# 358
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Alanable
# 362
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=d0m1A
# 363
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=shogaN_pN
# 365
# 366
# Unable to compute stats, may be error with map used
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Cbowlbs
# 368
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=DamVowzki
# 369
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=r3trdk1ller
# 370
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Gr1me-
# 371
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=unpointed
# 373
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=paper_boyy
# 378
# match_id for CSGO
# 379
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=petitavocat
# 380
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=RyofuHousen
# 381
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=DyGodLiNG
# 384
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=zaprost0
# 385
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=hunger
# 386
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ha1i62
# 387
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Ryusukez
# 388
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-wist
# 393
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Boberto4
# 394
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=dEnZa25
# 395
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=dopamineX
# 396
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=InnRg
# 398
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=Dervinski
# 400
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=daveyG
# 403
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=AR1UKAAA
# 405
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=ZOotYy
# 406
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=NiGeMoX
# 409
# match_id for CSGO
# 413
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=1337_casual
# 414
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=-Prest0n
# 416
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=m5gunner
# 418
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=_C0br4_
# 419
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=SEN2_KBRN
# 422
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=0000000013
# 427
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=HEADREMOVER
# 429
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=--Insan1ty--
# 430
# Error 404: Resource not found. Requested URL: https://open.faceit.com/data/v4/players?nickname=danksterr
# 431
